# %%
dir.create("~/rlib")
.libPaths(c("~/rlib", .libPaths()))
install.packages("BH", repos="https://cloud.r-project.org")
# Out:
# Warning message in dir.create("~/rlib"):
# “'/home/cosmo/rlib' already exists”
# Installing package into ‘/home/cosmo/rlib’
# (as ‘lib’ is unspecified)

# %%
library(BH)

# %%
.libPaths()
# Out:
# [1] "/home/cosmo/rlib"              "/usr/local/lib/R/site-library"
# [3] "/usr/lib/R/site-library"       "/usr/lib/R/library"

# %%
.libPaths(c("~/rlib", .libPaths()))
example(stan_model, package = "rstan", run.dontrun = TRUE)
# Out:
# Loading required package: StanHeaders
#
# Loading required package: ggplot2
#
# rstan (Version 2.21.2, GitRev: 2e1f913d3ca3)
#
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
# stn_md> stancode <- 'data {real y_mean;} parameters {real y;} model {y ~ normal(y_mean,1);}'
#
# stn_md> mod <- stan_model(model_code = stancode, verbose = TRUE)
#
# TRANSLATING MODEL '16a540c6086086816528e4524def24d9' FROM Stan CODE TO C++ CODE NOW.
# successful in parsing the Stan model '16a540c6086086816528e4524def24d9'.
# OS: aarch64, linux-gnu; rstan: 2.21.2; Rcpp: 1.0.6; inline: 0.3.17
#  >> setting environment variables:
# PKG_LIBS =  '/usr/lib/R/site-library/rstan/lib//libStanServices.a' -L'/usr/lib/R/site-library/StanHeaders/lib/' -lStanHeaders -L'/usr/lib/R/site-library/RcppParallel/libs/' -ltbb
# ...
